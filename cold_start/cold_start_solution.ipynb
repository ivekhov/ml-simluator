# %%
import pandas as pd
import os 
import math

# %%
df = pd.read_csv('./data.csv')

# %%
df.head()
# Out:
#    id      monday  product_id  category  sales
# 0   0  2020-01-05          14        14   45.0
# 1   1  2020-01-05          82        10    NaN
# 2   2  2020-01-05          42         4   62.0
# 3   3  2020-01-05          90         3    NaN
# 4   4  2020-01-05          67        19   38.0

# %%
cats = df.groupby('category', dropna=False)['sales'].mean()
cats
# Out:
# category
# 2     53.5
# 3      NaN
# 4     62.0
# 10     1.0
# 14    50.0
# 18     NaN
# 19    38.0
# Name: sales, dtype: float64

# %%
df
# Out:
#    id      monday  product_id  category  sales
# 0   0  2020-01-05          14        14   45.0
# 1   1  2020-01-05          82        10    NaN
# 2   2  2020-01-05          42         4   62.0
# 3   3  2020-01-05          90         3    NaN
# 4   4  2020-01-05          67        19   38.0
# 5   5  2020-01-05          36        10    1.0
# 6   6  2020-01-05          71        18    NaN
# 7   7  2020-01-05          47         2   41.0
# 8   8  2020-01-05          68         2   66.0
# 9   9  2020-01-05           9        14   55.0

# %%
df.fillna(
    df.groupby('category')['sales'].mean()
)
# Out:
#    id      monday  product_id  category  sales
# 0   0  2020-01-05          14        14   45.0
# 1   1  2020-01-05          82        10    NaN
# 2   2  2020-01-05          42         4   62.0
# 3   3  2020-01-05          90         3    NaN
# 4   4  2020-01-05          67        19   38.0
# 5   5  2020-01-05          36        10    1.0
# 6   6  2020-01-05          71        18    NaN
# 7   7  2020-01-05          47         2   41.0
# 8   8  2020-01-05          68         2   66.0
# 9   9  2020-01-05           9        14   55.0

# %%
df.groupby('category', as_index=False)['sales'].mean()
# Out:
#    category  sales
# 0         2   53.5
# 1         3    NaN
# 2         4   62.0
# 3        10    1.0
# 4        14   50.0
# 5        18    NaN
# 6        19   38.0

# %%
def f(row, target, dict_keys, group):
    if math.isnan(row[target]):
        row[target] = dict_keys[group]

# %%
df.apply(f, axis = 0)

# %%
# df.join(cats, on='category', how='left', lsuffix='df', rsuffix='cats')

# %%
df[df['sales'].isnull()]
# Out:
#    id      monday  product_id  category  sales
# 1   1  2020-01-05          82        10    NaN
# 3   3  2020-01-05          90         3    NaN
# 6   6  2020-01-05          71        18    NaN

# %%
df
# Out:
#    id      monday  product_id  category  sales
# 0   0  2020-01-05          14        14   45.0
# 1   1  2020-01-05          82        10    1.0
# 2   2  2020-01-05          42         4   62.0
# 3   3  2020-01-05          90         3    NaN
# 4   4  2020-01-05          67        19   38.0
# 5   5  2020-01-05          36        10    1.0
# 6   6  2020-01-05          71        18    NaN
# 7   7  2020-01-05          47         2   41.0
# 8   8  2020-01-05          68         2   66.0
# 9   9  2020-01-05           9        14   55.0

# %%
df = pd.read_csv('./data.csv')
df
# Out:
#    id      monday  product_id  category  sales
# 0   0  2020-01-05          14        14   45.0
# 1   1  2020-01-05          82        10    NaN
# 2   2  2020-01-05          42         4   62.0
# 3   3  2020-01-05          90         3    NaN
# 4   4  2020-01-05          67        19   38.0
# 5   5  2020-01-05          36        10    1.0
# 6   6  2020-01-05          71        18    NaN
# 7   7  2020-01-05          47         2   41.0
# 8   8  2020-01-05          68         2   66.0
# 9   9  2020-01-05           9        14   55.0

# %%
# !!!! solution
df['sales2'] = df['sales']
df['sales2'] = df.groupby('category')['sales2'].transform(lambda x: x.fillna(x.mean()) )
df
# Out:
#    id      monday  product_id  category  sales  sales2
# 0   0  2020-01-05          14        14   45.0    45.0
# 1   1  2020-01-05          82        10    NaN     1.0
# 2   2  2020-01-05          42         4   62.0    62.0
# 3   3  2020-01-05          90         3    NaN     NaN
# 4   4  2020-01-05          67        19   38.0    38.0
# 5   5  2020-01-05          36        10    1.0     1.0
# 6   6  2020-01-05          71        18    NaN     NaN
# 7   7  2020-01-05          47         2   41.0    41.0
# 8   8  2020-01-05          68         2   66.0    66.0
# 9   9  2020-01-05           9        14   55.0    55.0

# %%
df['sales'] = df.groupby('category')['sales'].transform(lambda x: x.fillna(x.mean()) )
df
# Out:
#    id      monday  product_id  category  sales
# 0   0  2020-01-05          14        14   45.0
# 1   1  2020-01-05          82        10    1.0
# 2   2  2020-01-05          42         4   62.0
# 3   3  2020-01-05          90         3    NaN
# 4   4  2020-01-05          67        19   38.0
# 5   5  2020-01-05          36        10    1.0
# 6   6  2020-01-05          71        18    NaN
# 7   7  2020-01-05          47         2   41.0
# 8   8  2020-01-05          68         2   66.0
# 9   9  2020-01-05           9        14   55.0

# %%
df2 = df.copy()
df2
# Out:
#    id      monday  product_id  category  sales
# 0   0  2020-01-05          14        14   45.0
# 1   1  2020-01-05          82        10    NaN
# 2   2  2020-01-05          42         4   62.0
# 3   3  2020-01-05          90         3    NaN
# 4   4  2020-01-05          67        19   38.0
# 5   5  2020-01-05          36        10    1.0
# 6   6  2020-01-05          71        18    NaN
# 7   7  2020-01-05          47         2   41.0
# 8   8  2020-01-05          68         2   66.0
# 9   9  2020-01-05           9        14   55.0

# %%
df = pd.read_csv('./data.csv')

def fillna_with_mean(df: pd.DataFrame, target: str, group: str) -> pd.DataFrame:
    result = df.copy()
    result[target] = result.groupby(group)[target].transform(lambda x: x.fillna(x.mean()))
    return result

fillna_with_mean(df, 'sales', 'category')
# Out:
#    id      monday  product_id  category  sales
# 0   0  2020-01-05          14        14   45.0
# 1   1  2020-01-05          82        10    1.0
# 2   2  2020-01-05          42         4   62.0
# 3   3  2020-01-05          90         3    NaN
# 4   4  2020-01-05          67        19   38.0
# 5   5  2020-01-05          36        10    1.0
# 6   6  2020-01-05          71        18    NaN
# 7   7  2020-01-05          47         2   41.0
# 8   8  2020-01-05          68         2   66.0
# 9   9  2020-01-05           9        14   55.0

# %%
# df.groupby('category')['sales'].transform(lambda x: x.fillna(x.mean()))


# df.groupby("category").transform(lambda x: x.fillna(x.mean()))

# df['sales'] = df['sales'].fillna(df.groupby('category')['sales'].transform('mean'))

# df.groupby("name").transform(lambda x: x.fillna(x.mean()))

# df['sales'] = df['sales'].fillna(df.groupby('category')['sales'].transform('mean'))

# df

# %%
! pip install pyment
# Out:
# ...
#   Using cached Pyment-0.3.3-py2.py3-none-any.whl (21 kB)
# ...
